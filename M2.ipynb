# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('Solar.csv')

# %%
data.head()
# Out:
#    Day of Year  Year  Month  Day  First Hour of Period  Is Daylight  \
# 0          245  2008      9    1                     1        False
# 1          245  2008      9    1                     4        False
# 2          245  2008      9    1                     7         True
# 3          245  2008      9    1                    10         True
# 4          245  2008      9    1                    13         True
#
#    Distance to Solar Noon  Average Temperature (Day)  \
# 0                0.859897                         69
# 1                0.628535                         69
# 2                0.397172                         69
# 3                0.165810                         69
# 4                0.065553                         69
#
#    Average Wind Direction (Day)  Average Wind Speed (Day)  Sky Cover  \
# 0                            28                       7.5          0
# 1                            28                       7.5          0
# ...

# %%
df = data.dropna()

# %%
df.head()
# Out:
#    Day of Year  Year  Month  Day  First Hour of Period  Is Daylight  \
# 0          245  2008      9    1                     1        False
# 1          245  2008      9    1                     4        False
# 2          245  2008      9    1                     7         True
# 3          245  2008      9    1                    10         True
# 4          245  2008      9    1                    13         True
#
#    Distance to Solar Noon  Average Temperature (Day)  \
# 0                0.859897                         69
# 1                0.628535                         69
# 2                0.397172                         69
# 3                0.165810                         69
# 4                0.065553                         69
#
#    Average Wind Direction (Day)  Average Wind Speed (Day)  Sky Cover  \
# 0                            28                       7.5          0
# 1                            28                       7.5          0
# ...

# %%
df.shape
# Out:
# (2919, 16)

# %%
df = df.rename(columns={'Day of Year':'Day_of_Year','Is Daylight':'Is_Daylight','First Hour of Period':'First_Hour_of_Period','Is Daylight':'Is_Daylight','Distance to Solar Noon':'Distance_to_Solar_Noon','Average Temperature (Day)':'Average_Temperature','Average Wind Direction (Day)':'Average_Wind_Direction','Average Wind Speed (Day)':'Average_Wind_Speed','Sky Cover':'Sky_Cover','Relative Humidity':'Relative_Humidity','Average Wind Speed (Period)':'Average_Wind_Speed','Average Barometric Pressure (Period)':'Average_Barometric_Pressure','Power Generated':'Power_Generated'})

# %%
df.head()
# Out:
#    Day_of_Year  Year  Month  Day  First_Hour_of_Period  Is_Daylight  \
# 0          245  2008      9    1                     1        False
# 1          245  2008      9    1                     4        False
# 2          245  2008      9    1                     7         True
# 3          245  2008      9    1                    10         True
# 4          245  2008      9    1                    13         True
#
#    Distance_to_Solar_Noon  Average_Temperature  Average_Wind_Direction  \
# 0                0.859897                   69                      28
# 1                0.628535                   69                      28
# 2                0.397172                   69                      28
# 3                0.165810                   69                      28
# 4                0.065553                   69                      28
#
#    Average_Wind_Speed  Sky_Cover  Visibility  Relative_Humidity  \
# ...

# %%
df.columns
# Out:
# Index(['Day_of_Year', 'Year', 'Month', 'Day', 'First_Hour_of_Period',
#        'Is_Daylight', 'Distance_to_Solar_Noon', 'Average_Temperature',
#        'Average_Wind_Direction', 'Average_Wind_Speed', 'Sky_Cover',
#        'Visibility', 'Relative_Humidity', 'Average_Wind_Speed',
#        'Average_Barometric_Pressure', 'Power_Generated'],
#       dtype='object')

# %%
plt.hist(df['Average_Temperature'],color="red")
plt.xlabel("Average_Temperature")
plt.show()

# %%
plt.hist(df['Average_Wind_Direction'],color="red")
plt.xlabel("Average_Wind_Direction")
plt.show()

# %%
df['Is_Daylight'] = df['Is_Daylight'].map({True : 1, False : 0})

# %%
df.head()
# Out:
#    Day_of_Year  Year  Month  Day  First_Hour_of_Period  Is_Daylight  \
# 0          245  2008      9    1                     1            0
# 1          245  2008      9    1                     4            0
# 2          245  2008      9    1                     7            1
# 3          245  2008      9    1                    10            1
# 4          245  2008      9    1                    13            1
#
#    Distance_to_Solar_Noon  Average_Temperature  Average_Wind_Direction  \
# 0                0.859897                   69                      28
# 1                0.628535                   69                      28
# 2                0.397172                   69                      28
# 3                0.165810                   69                      28
# 4                0.065553                   69                      28
#
#    Average_Wind_Speed  Sky_Cover  Visibility  Relative_Humidity  \
# ...

# %%
plt.figure(figsize=(10,6))
plt.plot(df['Average_Temperature'])
plt.show()

# %%
# Heatmap plot diagram
fig, ax = plt.subplots(figsize=(18,13))
sns.heatmap(df.corr(), ax=ax, annot=True)
# Out:
# <AxesSubplot:>

# %%
boxplot = df.boxplot(column=['Average_Temperature'], figsize=(8,6),  fontsize=15)
plt.show()

# %%
def PropByVar(df, variable):
    dataframe_pie = df[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(8,12), autopct='%1.2f%%', fontsize = 12)
    ax.set_title(variable + ' \n', fontsize = 15)
    plt.show()
    return np.round(dataframe_pie/df.shape[0]*100,2)
PropByVar(df,"Is_Daylight")
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.scatter(df["Average_Temperature"],df["Power_Generated"],color="red")

# %%
data1=df.iloc[:,:9]
data2=df.iloc[:,9:-1]

# %%
a=pd.plotting.scatter_matrix(data1, alpha=0.05, figsize=(18,10), diagonal='hist')
axis = 'off'

plt.show()
